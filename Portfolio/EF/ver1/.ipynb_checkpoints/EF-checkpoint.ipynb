# %%
# Pandas and numpy for data manipulation
import pandas as pd
import numpy as np

# ignore warnings
import warnings
warnings.filterwarnings('ignore')

from datetime import datetime

import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from matplotlib import style
# %matplotlib inline

#векторный формат
# %config InlineBackend.figure_format = 'svg'

# %%
plt.style.use('default')
plt.rcParams['figure.figsize'] = [16, 4]
plt.rcParams['figure.dpi'] = 200
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ## 1. Прогружаем данные

# %%
table = pd.read_csv('Data/SPY.csv', index_col='Date', parse_dates=True)
EWJ = pd.read_csv('Data/EWJ.csv', index_col='Date', parse_dates=True)

# %%
table = table.iloc[1:]

# %%
print(len(EWJ))
print(len(table))
# Out:
# 281
# 281

# %%
table['SPY'] = table['Adj Close']
table['EWJ'] = EWJ['Adj Close']

# %%
del table['Open']
del table['High']
del table['Low']
del table['Close']
del table['Adj Close']
del table['Volume']

# %%
table.head()
# Out:
#                   SPY        EWJ
# Date
# 1996-03-01  42.334843  47.236946
# 1996-04-01  42.985065  49.495285
# 1996-05-01  43.960846  47.236946
# 1996-06-01  44.114925  47.801540
# 1996-07-01  42.355808  45.543198

# %%
table['SPY'] = table['SPY'].str.replace(',', '').astype(float)

# %%
table['EWJ'] = table['EWJ'].astype(float)

# %%
#table['BTC'] = table['BTC'].str.replace(',', '').astype(float)

# %%
#table['ETH'] = table['ETH'].str.replace(',', '').astype(float)

# %%
#table['LTC'] = table['LTC'].astype(float)

# %%
#сделаем инверсию таблицы с котировками
#table = table[-1:1:-1]

# %% [markdown]
# ## 2. Смотрим динамику курса

# %%
figure(figsize=(12, 4))
plt.plot(table['SPY'], color='green', marker='', linestyle='-', markerfacecolor='blue', label = 'SPY');
plt.grid(linestyle='--', linewidth=0.5)

#plt.legend(loc='upper center', ncol=2);
plt.legend(loc='best');        

#Подписи для осей:
#plt.xlabel('time', fontsize=10)
plt.ylabel('USD', fontsize=9);

#Диапазон осей:
#plt.xlim('2016-03-14', '2019-08-01');
#plt.ylim(0, 3000);

# Градуировка осей
#plt.yticks(range(0, 3200, 500), fontsize=12)

#Заголовок:
plt.title('Динамика курса', fontsize=10, y=1.05);

# %%
figure(figsize=(12, 4))
plt.plot(table['EWJ'], color='green', marker='', linestyle='-', markerfacecolor='blue', label = 'SPY');
plt.grid(linestyle='--', linewidth=0.5)

#plt.legend(loc='upper center', ncol=2);
plt.legend(loc='best');        

#Подписи для осей:
#plt.xlabel('time', fontsize=10)
plt.ylabel('USD', fontsize=9);

#Диапазон осей:
#plt.xlim('2016-03-14', '2019-08-01');
#plt.ylim(0, 3000);

# Градуировка осей
#plt.yticks(range(0, 3200, 500), fontsize=12)

#Заголовок:
plt.title('Динамика курса', fontsize=10, y=1.05);

# %% [markdown]
# ## 3. Взаимная корреляция

# %%
table.head()
# Out:
#                   SPY        EWJ
# Date
# 1996-03-01  42.334843  47.236946
# 1996-04-01  42.985065  49.495285
# 1996-05-01  43.960846  47.236946
# 1996-06-01  44.114925  47.801540
# 1996-07-01  42.355808  45.543198

# %%
table.corr()
# Out:
#           SPY       EWJ
# SPY  1.000000  0.747507
# EWJ  0.747507  1.000000

# %% [markdown]
# ## 4. Доходность каждого из активов

# %% [markdown]
# Доходность (Rate of Return) – это относительный прирост стоимости актива в каждом из периодов по отношению к предыдущему значению:
# $$
# ROR(t_i) = \frac{Close(t_i)}{Close(t_{i-1})} - 1 , \ i = 1,\ldots,n
# $$

# %%
close = table['SPY'].values.copy()
ror = np.diff(close) / close[:-1]

# %%
aror = (ror + 1.).cumprod() - 1.

# %%
years_total = aror.size / 12
cagr = ((aror[-1] + 1.)/(aror[0] + 1.)) ** (1 / years_total) - 1.
print('Среднегодовая доходность = ', round(cagr*100, 2),'%')
# Out:
# Среднегодовая доходность =  8.64 %

# %% [markdown]
# ## 5. Построение границы эффективности

# %%
selected = ['SPY', 'EWJ']

# %%
returns_daily = table.pct_change()
returns_annual = returns_daily.mean() * 250

# %%
# get daily and covariance of returns of the stock
cov_daily = returns_daily.cov()
cov_annual = cov_daily * 250

# %%
# empty lists to store returns, volatility and weights of imiginary portfolios
port_returns = []
port_volatility = []
stock_weights = []
sharpe_ratio = []

# %%
# set the number of combinations for imaginary portfolios
num_assets = len(selected)
num_portfolios = 9000

# %%
#set random seed for reproduction's sake
np.random.seed(101)

# %%
# populate the empty lists with each portfolios returns,risk and weights
for single_portfolio in range(num_portfolios):
    weights = np.random.random(num_assets)
    weights /= np.sum(weights)
    returns = np.dot(weights, returns_annual)
    volatility = np.sqrt(np.dot(weights.T, np.dot(cov_annual, weights)))
    sharpe = returns / volatility
    sharpe_ratio.append(sharpe)
    port_returns.append(returns)
    port_volatility.append(volatility)
    stock_weights.append(weights)

# %%
# a dictionary for Returns and Risk values of each portfolio
portfolio = {'Returns': port_returns,
             'Volatility': port_volatility,
             'Sharpe Ratio': sharpe_ratio}

# %%
# extend original dictionary to accomodate each ticker and weight in the portfolio
for counter,symbol in enumerate(selected):
    portfolio[symbol+' Weight'] = [Weight[counter] for Weight in stock_weights]

# %%
# make a nice dataframe of the extended dictionary
df = pd.DataFrame(portfolio)

# %%
# get better labels for desired arrangement of columns
column_order = ['Returns', 'Volatility', 'Sharpe Ratio'] + [stock+' Weight' for stock in selected]

# %%
# reorder dataframe columns
df = df[column_order]

# %%
df.tail()
# Out:
#        Returns  Volatility  Sharpe Ratio  SPY Weight  EWJ Weight
# 8995  0.702047    0.776286      0.904366    0.151087    0.848913
# 8996  0.633368    0.793156      0.798542    0.105579    0.894421
# 8997  1.225417    0.682236      1.796178    0.497890    0.502110
# 8998  1.138539    0.693045      1.642807    0.440321    0.559679
# 8999  1.263985    0.678126      1.863938    0.523446    0.476554

# %%
# plot frontier, max sharpe & min Volatility values with a scatterplot
plt.style.use('seaborn-dark')
df.plot.scatter(x='Volatility', y='Returns', c='Sharpe Ratio',
                cmap='RdYlGn', edgecolors='black', figsize=(10, 8), grid=True)
plt.xlabel('Volatility (Std. Deviation)')
plt.ylabel('Expected Returns')
plt.title('Efficient Frontier')
plt.show()

# %% [markdown]
# ## 6. Оптимальное соотношение активов

# %%
# find min Volatility & max sharpe values in the dataframe (df)
min_volatility = df['Volatility'].min()
max_sharpe = df['Sharpe Ratio'].max()

# use the min, max values to locate and create the two special portfolios
sharpe_portfolio = df.loc[df['Sharpe Ratio'] == max_sharpe]
min_variance_port = df.loc[df['Volatility'] == min_volatility]

# plot frontier, max sharpe & min Volatility values with a scatterplot
plt.style.use('seaborn-dark')
df.plot.scatter(x='Volatility', y='Returns', c='Sharpe Ratio',
                cmap='RdYlGn', edgecolors='black', figsize=(10, 8), grid=True)
plt.scatter(x=sharpe_portfolio['Volatility'], y=sharpe_portfolio['Returns'], c='red', marker='D', s=200)
plt.scatter(x=min_variance_port['Volatility'], y=min_variance_port['Returns'], c='blue', marker='D', s=200 )
plt.xlabel('Volatility (Std. Deviation)')
plt.ylabel('Expected Returns')
plt.title('Efficient Frontier')
plt.show()

# %%
# print the details of the 2 special portfolios
print(min_variance_port.T)
print(sharpe_portfolio.T)
# Out:
#                   7283
# Returns       1.592399
# Volatility    0.661341
# Sharpe Ratio  2.407833
# SPY Weight    0.741065
# EWJ Weight    0.258935
#                   2328
# Returns       1.982233
# Volatility    0.684874
# Sharpe Ratio  2.894301
# SPY Weight    0.999382
# EWJ Weight    0.000618
