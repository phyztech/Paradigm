# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('bridgewater.csv', index_col = 1)

# %%
df.head(24)
# Out:
#                                                     Stock  Type  Shares Held  \
# Symbol
# SPY                                Spdr s&p 500 etf trust   NaN    6989665.0
# VWO                    Vanguard ftse emerging markets etf   NaN   24757646.0
# IVV                              Ishares core s&p 500 etf   NaN    2188003.0
# GLD                                       Spdr gold trust   NaN    4056627.0
# EWZ                        Ishares msci brazil capped etf   NaN   10987334.0
# IEMG               Ishares core msci emerging markets etf   NaN    7916557.0
# LQD     Ishares iboxx investment grade corporate bond ...   NaN    2330933.0
# HYG              Ishares iboxx $ high yield corp bond etf   NaN    3060858.0
# TLT                    Ishares 20+ year treasury bond etf   NaN    1939329.0
# EFA                          Ishares msci eafe index fund   NaN    2714309.0
# VEA                   Vanguard ftse developed markets etf   NaN    4277546.0
# ...

# %%
df = df.drop(['Market Value', 'Type', 'source_type', '% Ownership', 'Shares Held', '% Change', 'Change in shares'], axis=1)
df = df.drop(['ARCC'], axis=0)

# %%
df.head(24)
# Out:
#                                                     Stock  % of Portfolio  \
# Symbol
# SPY                                Spdr s&p 500 etf trust         22.9697
# VWO                    Vanguard ftse emerging markets etf         11.2411
# IVV                              Ishares core s&p 500 etf          7.2211
# GLD                                       Spdr gold trust          5.9187
# EWZ                        Ishares msci brazil capped etf          5.3230
# IEMG               Ishares core msci emerging markets etf          4.3454
# LQD     Ishares iboxx investment grade corporate bond ...          3.0453
# HYG              Ishares iboxx $ high yield corp bond etf          2.7483
# TLT                    Ishares 20+ year treasury bond etf          2.6826
# EFA                          Ishares msci eafe index fund          1.9244
# VEA                   Vanguard ftse developed markets etf          1.9243
# EWT                        Ishares msci taiwan capped etf          1.8511
# ...

# %%
df['% of Portfolio'].sum()
# Out:
# 82.6898
